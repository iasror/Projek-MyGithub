# %%
import numpy as np
np.random.seed(0)
import mltools as ml
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Extract and split data

# %%
curve=np.genfromtxt("data/curve80.txt")
print (curve.shape)
X=curve[:,0] #features
#X=X #[:,np.newaxis] #force to be shape (M,1)
y=curve[:,1] #target 
#y=y #[:,np.newaxis]
print(X.shape,y.shape)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0) #ml.splitData(X, y, 0.70)
#print(X_train.shape)
# Out:
# (506, 13)
# (506, 13) (506,)

# %% [markdown]
# ## Using linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# train the model
lr = LinearRegression().fit(X_train, y_train)
ytrain_predict=lr.predict(X_train)
ytest_predict = lr.predict(X_test)

mse_train = mean_squared_error(y_train,ytrain_predict)
mse_test = mean_squared_error(y_test,ytest_predict)

print("Weights (coefficients): {}".format(lr.coef_))
print("Bias (intercept): {}".format(lr.intercept_))
print("Training MSE: ", mse_train)
print("Test MSE:", mse_test)
# Out:
# Weights (coefficients): [ -1.16869578e-01   4.39939421e-02  -5.34808462e-03   2.39455391e+00
#   -1.56298371e+01   3.76145473e+00  -6.95007160e-03  -1.43520477e+00
#    2.39755946e-01  -1.12937318e-02  -9.86626289e-01   8.55687565e-03
#   -5.00029440e-01]
# Bias (intercept): 36.98045533762024
# Training MSE:  19.6426616728
# Test MSE: 29.7905591642

# %%
fig, ax = plt.subplots()
ax.scatter(y_train, ytrain_predict, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %% [markdown]
# # Polynomial features

# %%
# create polynomial features
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

poly = PolynomialFeatures(degree=2)
X_train2 = poly.fit_transform(X_train[:,np.newaxis])

print (X_train2[0:6,:])# look at the same data points -- same values
# Out:
# [[  1.00000000e+00   1.91330000e-01   3.66071689e-02]
#  [  1.00000000e+00   1.03280000e-01   1.06667584e-02]
#  [  1.00000000e+00   1.04690000e-01   1.09599961e-02]
#  [  1.00000000e+00   8.71675000e+00   7.59817306e+01]
#  [  1.00000000e+00   1.08342000e+01   1.17379890e+02]
#  [  1.00000000e+00   1.05740000e-01   1.11809476e-02]]

# %%
import mltools.transforms as xform

degrees = np.array(range(1,30))
learners = [ [] ]*30
errT = np.zeros((30,))
errV = np.zeros((30,))
plt.rcParams['figure.figsize'] = (8.0, 5.0)
fig,ax = plt.subplots(2,3)
axFlat = [a for row in ax for a in row] # 2x3 subplots as simple list
i=0


for d in degrees:
    
    poly = PolynomialFeatures(degree=d)
    X_trainP = poly.fit_transform(X_train[:,np.newaxis])
    X_testP = poly.fit_transform(X_test[:,np.newaxis])
    
    
    xs = np.linspace(1, 20, 100)
    Xs =poly.fit_transform(xs[:,np.newaxis])
    
    #X_trainP = xform.rescale(X_trainP)
    #X_testP = xform.rescale(X_testP)
    
    learners[d] = linear_model.LinearRegression()
    learners[d].fit(X_trainP, y_train)
        
    mse_train = mean_squared_error(y_train,learners[d].predict(X_trainP))
    mse_test = mean_squared_error(y_test,learners[d].predict(X_testP))
    
    errT[d] = mse_train
    errV[d] = mse_test
    
    if d in [1,3,5,7,15,29]:
        axFlat[i].plot(X_train,y_train,'r.',X_test,y_test,'g.',markersize=8)
        axFlat[i].set_title("Degree {}".format(d))
        

        #Xs = poly.fit_transform(Xs)
        ys = learners[d].predict(Xs)
        
        axFlat[i].plot(xs,ys,'k-',linewidth=3)
        
        axFlat[i].axis(axisSize)
        i += 1

# %%
print(degrees.shape)
print(errV.shape)
plt.rcParams['figure.figsize'] = (5.0, 4.0)
plt.semilogy(degrees[0:29],errT[0:29],'r-',degrees[0:29],errV[0:29],'g-',linewidth=2);
# Out:
# (29,)
# (30,)

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

clf = Ridge(alpha=10000)
clf.fit(X_train[:,np.newaxis], y_train) 

ytr_ridge=lr.predict(X_train[:,np.newaxis])
yts_ridge = lr.predict(X_test[:,np.newaxis])

mse_train = mean_squared_error(y_train,ytr_ridge)
mse_test = mean_squared_error(y_test,yts_ridge)

print(mse_train)
print(mse_test)
# Out:
# 542.824508988
# 457.87284627

# %%
### compare to ols
Training MSE:  1.39208362041
Test MSE: 1.43349039919
# Out:
#   File "<ipython-input-458-88ecf86a52a1>", line 2
#     Training MSE:  1.39208362041
#                ^
# SyntaxError: invalid syntax
